# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanoridolfi/Coding_ML/blob/master/2_level__con_Bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
commento="VERSIONE con BIAS"
import matplotlib.pyplot as plt
import random
import numpy as np

from mpl_toolkits.mplot3d import Axes3D

from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter


@np.vectorize
def generaPunti(n):
    l=[]
    for i in range(0, n+1):
        x = random.random()*300-150
        y = random.random()*300-150
        l.append([x,y])
    return l
def posizione(punto,xa,xb,ya,yb):
    if (punto[0]>xa and punto[0]<xb and punto[1]>ya and punto[1]<yb):
    #if (punto[0]>xa and  punto[1]<yb):
    #if (punto[0]>xa):
      formato = 'ro'
      out=1
    else:
      formato = 'go'
      out=0
    return out,formato

def posizione_neurale(p):
    if p>0.2:
      formato = 'ro'
      out=1
    else:
      formato = 'go'
      out=0
    return out,formato



def sigmoid(x):
    return 1 / (1 + np.e ** -x)
activation_function = sigmoid

'''
Creo matrice dei pesi. Input sono 3, x1,x2 e x3 che è BIAS. Il vettore X ha dimensioni 1x3. Lo strato hidden è composto da 4 uscite, y1,y2,y3 e y4 ed è rappresentato dal vettore Y di dimensioni 4x1
Il vettore Y, di dimensioni 4x1 è il risultato del prodotto Wih.dot.X La matrice Wih ha dimensioni 4x3. Y=Wih.dot.X (4x1=4x3.dot.3x1)
L'output Z ha dimensioni 1. La matrice dei pesi da Y a Z,matrice Who,  ha dimensione 1x4. L'output Z ha dimensioni 1x1. Per questo Z=Who.dot.Y (1x1=1x4.dot.4x1)  
'''
#Creo punti Input per training. Per ogni punto aggiungo un campo che vale 1 se il punto è nel quadrato, 0 se è fuori. Nel disegno 1 è punto rosso 0 è punto verde
# defnisco contorni del quadrato
xa=-50
xb=50
ya=-50
yb=50
learning_rate=0.01
n=40000
hid=50
training_set=[]
# Set di trainig formato da n punti
ListaPunti= generaPunti(n)
for punto in ListaPunti:
   training_set.append([punto[0],punto[1],posizione(punto,xa,xb,ya,yb)[0]])
# punto[2] è la posizione corretta del punto, che vale 1 se è all'interno del quadrato e 0 se è fuori il quadrato   
#print(training_set)

# Creo la matrice Wih, hid x2, i cui elementi sono i pesi. I pesi hanno un valore con distrubuzione gaussiano vm==0 e varianza=1
Wih=np.random.randn(hid,2)
# Creo la matrice Who, 1xhid, i cui elementi sono i pesi. I pesi hanno un valore distrubuzione gaussiano vm==0 e varianza=1
Who=np.random.randn(1,hid)
# per vedere le dimensioni di un array in comando è :array.shape, esempio Wih.shape
# Inizializzo i valori dell'input con una lista. X=(x1,x2).

# Creo il vettore BIAS del livello nascosto il vettore ha dimensioni (hidx1)
b1=[]
for t in range(0,hid):
  b1.append(1)
b1=np.array(b1)
b1=b1.reshape(hid,1)

#Creo il vettore BIAS del livello di uscita, il vettore ha dimensioni (1 x 1)
b2=[]
for t in range(0,1):
  b2.append(1)
b2=np.array(b2)
b2=b2.reshape(1,1)
###############TRAINING################################ 
print("INIZIO TRAINING SET\n")
epoche=200
Epo=[]
Err_y=[]

for e in range(0,epoche):
  Err=0
  Err_rel=0
  for punto in training_set:
    X=(punto[0],punto[1])
# lo devo trasformare in un array altrimenti non posso fare operazioni vettoriali
    X=np.array(X)
    X=X.reshape(2,1)
  

 
#calcolo Y=Wih.dot.X
    Y=np.dot(Wih,X)
#Sommo ad Y il BIAS b1
    Y=Y+b1
 
#calcolo Y_act che è il vettore Y a cui ho applicato la funzione di attivazione
    Y_act=activation_function(Y)
  
# Y ha dimensione 4x1
# Calcolo Z=Who.dot.Y.T
    Z=np.dot(Who,Y_act)
#Sommo ad Z il BIAS b2
    Z=Z+b2
#calcolo Z_act che è il vettore Z a cui ho applicato la funzione di attivazione
    Z_act=activation_function(Z)
 
  #print("Z_act= ", Z_act, "pos_reale=", punto[2])
#calcolo l'errore finale E=valore_corretto - Z_act . Il valore corretto è la terza colonna dei punti di training, ovvero training_set[2]
    error_output=punto[2]-Z_act
    Err=Err+(error_output)**2
    # print("Errore= ",output_error)
#Calcolo il delta da sommare al corrente valore di Y_act: moltiplicazione di learning_rate*output_errore*derivata_sigmoide in Z*valore del vettore Y_act 
# la derivata della sigmoide calcolata nel punto Z_act è: Z_act(1-Z_act)!!
    uno_Z_act=(1-Z_act)
    tmp1=error_output*Z_act*uno_Z_act
    # tmp1 è il delta del livello di uscita
    tmp2=learning_rate*(np.dot(tmp1,Y_act.T))
    # Calcolo d_b2
    d_b2=np.sum(tmp1,axis=1, keepdims=True)
     
  
  # Calcolo matrice Wih
    error_hidden=np.dot(Who.T,tmp1)
    tmp3=error_hidden*Y_act*(1-Y_act)
    #tmp3 è il delta del livello finale
    U=np.dot(tmp3,X.T)
     # Calcolo d_b1
    d_b1=np.sum(tmp3,axis=1, keepdims=True)
  #aggiorno matrice dei pesi Wih
    Wih=Wih+learning_rate*U
   #aggiorno matrice dei pesi Who
    Who=Who+tmp2
   #aggiorno d_b1
    b1=b1+d_b1*learning_rate
   #aggiorno b2
    b2=b2+d_b2*learning_rate
  #print("dim tmp=",tmp.shape,",dim Z_act=", Z_act.shape,",dim (1-Z_act)=",uno_Z_act.shape, ",dim Z_act_deri=",Z_act_deri.shape,",dim Delta_Who=",Delta_Who.shape)
  #print("Z_act=", Z_act,",(1-Z_act)=",uno_Z_act, ",Z_act_deri=",Z_act_deri,",Delta_Who=",Delta_Who)
  #print("Who=", Who)

  Err_rel=(Err)/len(training_set)
  Epo.append(e)
  Err_y.append(Err_rel)
  print("epoca=",e,"Errore =",Err_rel)

######################FINE TRAINING#######################################
# TEST SET  
print("INIZIO TEST\n")
t=1000
test_set=[]
# Set di trainig formato da n punti
test_set= generaPunti(t)

for punto in test_set:
  plt.plot(punto[0],punto[1],posizione(punto,xa,xb,ya,yb)[1])
plt.title("Disposizione corretta dei punti")
plt.show()


# Grafico punti dedotti da rete neurale
errori_tot=0
for punto in test_set:
   X=(punto[0],punto[1])
   X=np.array(X)
   X=X.reshape(2,1)
   Y=np.dot(Wih,X)+b1
   Y_act=activation_function(Y)
   Z=np.dot(Who,Y_act)+b2
   Z_act=activation_function(Z)
   plt.plot(punto[0],punto[1],posizione_neurale(Z_act)[1])
  # plt.title("Punti Dedotti dalla rete neurale")
#plt.show()

# Grafico errori
Px_in=[]
Px_out=[]
Py_in=[]
Py_out=[]
Zgraph_in=[]
Zgraph_out=[]

errori_tot=0
for punto in test_set:
   X=(punto[0],punto[1])
   if posizione(punto,xa,xb,ya,yb)[0]==1:
     Px_in.append(punto[0])
     Py_in.append(punto[1])
     
   else:
     Px_out.append(punto[0])
     Py_out.append(punto[1])
    

   X=np.array(X)
   X=X.reshape(2,1)
   Y=np.dot(Wih,X)+b1
   Y_act=activation_function(Y)
   Z=np.dot(Who,Y_act)+b2
   Z_act=activation_function(Z)
   if posizione(punto,xa,xb,ya,yb)[0]==1:
     Zgraph_in.append([Z_act])
   else:
     Zgraph_out.append([Z_act])
   #print("Z_act:posizione correta",posizione_neurale(Z_act)[0],":",posizione(punto,xa,xb,ya,yb)[0])
   #plt.plot(punto[0],punto[1],posizione_neurale(Z_act)[1])
   #print("Posizione, Z_act,Neurale, Errore Assoluto=",posizione(punto,xa,xb,ya,yb)[0],":",Z_act,":",posizione_neurale(Z_act)[0],":",posizione(punto,xa,xb,ya,yb)[0]-Z_act)
   if posizione_neurale(Z_act)[0]!=posizione(punto,xa,xb,ya,yb)[0]:
     plt.plot(punto[0],punto[1], 'bx')
     #pint("Z_act:formato neurale, output neurale, posizione corretta",Z_act,posizione_neurale(Z_act)[1],",",posizione_neurale(Z_act)[0],posizione(punto,xa,xb,ya,yb)[0])
     errori_tot=errori_tot+1
plt.title("Punti dedotti e punti errati in blu")
plt.show()

Px_in=np.array(Px_in)
Px_out=np.array(Px_out)
Py_in=np.array(Py_in)
Py_out=np.array(Py_out)
Zgraph_in=np.array(Zgraph_in)
Zgraph_out=np.array(Zgraph_out)
#Px_in=Px_in.reshape(t+1,1)
#Py_out=Py_out.reshape(t+1,1)
#Px_in=Px_out.reshape(t+1,1)
#Py_out=PY_out.reshape(t+1,1)
#Zgraph_in=Zgraph_in.reshape(t+1,1)
#Zgraph_out=Zgraph_out.reshape(t+1,1)
#print("inside=",len(Px_in))
#print("outside=",len(Px_out))



fig = plt.figure()
ax = fig.gca(projection='3d')
xdata = Px_in
ydata = Py_in
zdata = Zgraph_in
ax.scatter3D(xdata, ydata, zdata, s=30, c='r', marker='o');
xdata = Px_out
ydata = Py_out
zdata = Zgraph_out
ax.scatter3D(xdata, ydata, zdata, s=30, c='g', marker='^');
# Plot the surface.
plt.show()
print("Punti inside=",len(np.array(Px_in)))
print("Punti outside=",len(np.array(Px_out)))
print(commento," punti training=",n," epoche=",epoche," punti test=",t, " learning_rate=",learning_rate, " neuroni strato nascosto=",hid)
print("errori totali=",errori_tot, "su", t, "%",(errori_tot/t)*100)
Epo=np.array(Epo)
Epo=Epo.reshape(len(Epo))
Err_y=np.array(Err_y)
Err_y=Err_y.reshape(len(Err_y))
plt.plot(Epo, Err_y, 'r-')
plt.title('Errore relativi per epoche')
plt.show()
# Out:
# INIZIO TRAINING SET
#
# epoca= 0 Errore = [[0.4974332]]
# epoca= 1 Errore = [[0.48497085]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:46: RuntimeWarning: overflow encountered in power
# epoca= 2 Errore = [[0.48098119]]
# epoca= 3 Errore = [[0.09921164]]
# epoca= 4 Errore = [[0.07436822]]
# epoca= 5 Errore = [[0.06536596]]
# epoca= 6 Errore = [[0.05585278]]
# epoca= 7 Errore = [[0.04994508]]
# epoca= 8 Errore = [[0.04611294]]
# epoca= 9 Errore = [[0.04335994]]
# epoca= 10 Errore = [[0.04104195]]
# epoca= 11 Errore = [[0.03992372]]
# epoca= 12 Errore = [[0.03836068]]
# epoca= 13 Errore = [[0.03708875]]
# epoca= 14 Errore = [[0.03613273]]
# epoca= 15 Errore = [[0.03591687]]
# epoca= 16 Errore = [[0.03539392]]
# epoca= 17 Errore = [[0.03460076]]
# epoca= 18 Errore = [[0.03436176]]
# epoca= 19 Errore = [[0.03291675]]
# epoca= 20 Errore = [[0.03342835]]
# epoca= 21 Errore = [[0.03287179]]
# epoca= 22 Errore = [[0.03278254]]
# epoca= 23 Errore = [[0.03146648]]
# epoca= 24 Errore = [[0.03189359]]
# epoca= 25 Errore = [[0.03136046]]
# epoca= 26 Errore = [[0.03010574]]
# epoca= 27 Errore = [[0.03042271]]
# epoca= 28 Errore = [[0.03104645]]
# epoca= 29 Errore = [[0.02985058]]
# epoca= 30 Errore = [[0.02832261]]
# epoca= 31 Errore = [[0.02916645]]
# epoca= 32 Errore = [[0.02806879]]
# epoca= 33 Errore = [[0.02759908]]
# epoca= 34 Errore = [[0.02725042]]
# epoca= 35 Errore = [[0.02771943]]
# epoca= 36 Errore = [[0.02733287]]
# epoca= 37 Errore = [[0.02826604]]
# epoca= 38 Errore = [[0.02672751]]
# epoca= 39 Errore = [[0.02791498]]
# epoca= 40 Errore = [[0.02640821]]
# epoca= 41 Errore = [[0.02667847]]
# epoca= 42 Errore = [[0.02741854]]
# epoca= 43 Errore = [[0.02660974]]
# epoca= 44 Errore = [[0.02508555]]
# epoca= 45 Errore = [[0.02747751]]
# epoca= 46 Errore = [[0.02568476]]
# epoca= 47 Errore = [[0.02611049]]
# epoca= 48 Errore = [[0.02431876]]
# epoca= 49 Errore = [[0.02453763]]
# epoca= 50 Errore = [[0.02562502]]
# epoca= 51 Errore = [[0.02525519]]
# epoca= 52 Errore = [[0.02558144]]
# epoca= 53 Errore = [[0.0252039]]
# epoca= 54 Errore = [[0.02516522]]
# epoca= 55 Errore = [[0.02488303]]
# epoca= 56 Errore = [[0.02387563]]
# epoca= 57 Errore = [[0.02375978]]
# epoca= 58 Errore = [[0.02653957]]
# epoca= 59 Errore = [[0.02379761]]
# epoca= 60 Errore = [[0.02326583]]
# epoca= 61 Errore = [[0.02329896]]
# epoca= 62 Errore = [[0.02348246]]
# epoca= 63 Errore = [[0.02375864]]
# epoca= 64 Errore = [[0.02317415]]
# epoca= 65 Errore = [[0.0230343]]
# epoca= 66 Errore = [[0.0232002]]
# epoca= 67 Errore = [[0.02418766]]
# epoca= 68 Errore = [[0.02260708]]
# epoca= 69 Errore = [[0.02264859]]
# epoca= 70 Errore = [[0.02288192]]
# epoca= 71 Errore = [[0.02327363]]
# epoca= 72 Errore = [[0.02313503]]
# epoca= 73 Errore = [[0.02174385]]
# epoca= 74 Errore = [[0.02208526]]
# epoca= 75 Errore = [[0.02246449]]
# epoca= 76 Errore = [[0.0218986]]
# epoca= 77 Errore = [[0.02337496]]
# epoca= 78 Errore = [[0.02163835]]
# epoca= 79 Errore = [[0.02242148]]
# epoca= 80 Errore = [[0.02264566]]
# epoca= 81 Errore = [[0.02194458]]
# epoca= 82 Errore = [[0.02102013]]
# epoca= 83 Errore = [[0.02234358]]
# epoca= 84 Errore = [[0.0216784]]
# epoca= 85 Errore = [[0.02273187]]
# epoca= 86 Errore = [[0.02244341]]
# epoca= 87 Errore = [[0.02333621]]
# epoca= 88 Errore = [[0.02382337]]
# epoca= 89 Errore = [[0.02195744]]
# epoca= 90 Errore = [[0.02149531]]
# epoca= 91 Errore = [[0.02149828]]
# epoca= 92 Errore = [[0.02211783]]
# epoca= 93 Errore = [[0.02228266]]
# epoca= 94 Errore = [[0.02158479]]
# epoca= 95 Errore = [[0.02204491]]
# epoca= 96 Errore = [[0.02041354]]
# epoca= 97 Errore = [[0.02120659]]
# epoca= 98 Errore = [[0.02225067]]
# epoca= 99 Errore = [[0.02131648]]
# epoca= 100 Errore = [[0.02182216]]
# epoca= 101 Errore = [[0.02079501]]
# epoca= 102 Errore = [[0.0214478]]
# epoca= 103 Errore = [[0.02167561]]
# epoca= 104 Errore = [[0.02159974]]
# epoca= 105 Errore = [[0.02165938]]
# epoca= 106 Errore = [[0.02176333]]
# epoca= 107 Errore = [[0.02098879]]
# epoca= 108 Errore = [[0.02194484]]
# epoca= 109 Errore = [[0.02110558]]
# epoca= 110 Errore = [[0.02123052]]
# epoca= 111 Errore = [[0.02126458]]
# epoca= 112 Errore = [[0.02058822]]
# epoca= 113 Errore = [[0.02012891]]
# epoca= 114 Errore = [[0.020754]]
# epoca= 115 Errore = [[0.02000067]]
# epoca= 116 Errore = [[0.02182221]]
# epoca= 117 Errore = [[0.02095954]]
# epoca= 118 Errore = [[0.01987122]]
# epoca= 119 Errore = [[0.02069162]]
# epoca= 120 Errore = [[0.02117581]]
# epoca= 121 Errore = [[0.02087919]]
# epoca= 122 Errore = [[0.02000337]]
# epoca= 123 Errore = [[0.02082033]]
# epoca= 124 Errore = [[0.01994017]]
# epoca= 125 Errore = [[0.02024664]]
# epoca= 126 Errore = [[0.01976534]]
# epoca= 127 Errore = [[0.02038642]]
# epoca= 128 Errore = [[0.02029902]]
# epoca= 129 Errore = [[0.02027593]]
# epoca= 130 Errore = [[0.02046802]]
# epoca= 131 Errore = [[0.02033552]]
# epoca= 132 Errore = [[0.02157641]]
# epoca= 133 Errore = [[0.02086143]]
# epoca= 134 Errore = [[0.02068283]]
# epoca= 135 Errore = [[0.02035789]]
# epoca= 136 Errore = [[0.02018865]]
# epoca= 137 Errore = [[0.02061639]]
# epoca= 138 Errore = [[0.01983815]]
# epoca= 139 Errore = [[0.02053764]]
# epoca= 140 Errore = [[0.02035126]]
# epoca= 141 Errore = [[0.02044946]]
# epoca= 142 Errore = [[0.0195182]]
# epoca= 143 Errore = [[0.01961635]]
# epoca= 144 Errore = [[0.01883935]]
# epoca= 145 Errore = [[0.01947612]]
# epoca= 146 Errore = [[0.01917975]]
# epoca= 147 Errore = [[0.01948967]]
# epoca= 148 Errore = [[0.01908516]]
# epoca= 149 Errore = [[0.01850714]]
# epoca= 150 Errore = [[0.01859757]]
# epoca= 151 Errore = [[0.01953014]]
# epoca= 152 Errore = [[0.01980602]]
# epoca= 153 Errore = [[0.01847361]]
# epoca= 154 Errore = [[0.01825549]]
# epoca= 155 Errore = [[0.01858346]]
# epoca= 156 Errore = [[0.01889942]]
# epoca= 157 Errore = [[0.01900606]]
# epoca= 158 Errore = [[0.0184896]]
# epoca= 159 Errore = [[0.01853626]]
# epoca= 160 Errore = [[0.01908783]]
# epoca= 161 Errore = [[0.01964659]]
# epoca= 162 Errore = [[0.01868879]]
# epoca= 163 Errore = [[0.01817488]]
# epoca= 164 Errore = [[0.01822876]]
# epoca= 165 Errore = [[0.01853479]]
# epoca= 166 Errore = [[0.01830694]]
# epoca= 167 Errore = [[0.01766003]]
# epoca= 168 Errore = [[0.01799877]]
# epoca= 169 Errore = [[0.01859956]]
# epoca= 170 Errore = [[0.01725235]]
# epoca= 171 Errore = [[0.0173851]]
# epoca= 172 Errore = [[0.01740089]]
# epoca= 173 Errore = [[0.01807917]]
# epoca= 174 Errore = [[0.01799658]]
# epoca= 175 Errore = [[0.0176482]]
# epoca= 176 Errore = [[0.01691024]]
# epoca= 177 Errore = [[0.01739065]]
# epoca= 178 Errore = [[0.0176591]]
# epoca= 179 Errore = [[0.01687345]]
# epoca= 180 Errore = [[0.01692005]]
# epoca= 181 Errore = [[0.01651576]]
# epoca= 182 Errore = [[0.01703511]]
# epoca= 183 Errore = [[0.01756419]]
# epoca= 184 Errore = [[0.01761911]]
# epoca= 185 Errore = [[0.01640398]]
# epoca= 186 Errore = [[0.01785743]]
# epoca= 187 Errore = [[0.01679006]]
# epoca= 188 Errore = [[0.01749826]]
# epoca= 189 Errore = [[0.01721932]]
# epoca= 190 Errore = [[0.01665532]]
# epoca= 191 Errore = [[0.01626984]]
# epoca= 192 Errore = [[0.01773622]]
# epoca= 193 Errore = [[0.01638924]]
# epoca= 194 Errore = [[0.01680105]]
# epoca= 195 Errore = [[0.01622849]]
# epoca= 196 Errore = [[0.01672473]]
# epoca= 197 Errore = [[0.01729997]]
# epoca= 198 Errore = [[0.01677682]]
# epoca= 199 Errore = [[0.01701747]]
# INIZIO TEST
# Punti inside= 117
# Punti outside= 884
# VERSIONE con BIAS  punti training= 40000  epoche= 200  punti test= 1000  learning_rate= 0.01  neuroni strato nascosto= 50
# errori totali= 31 su 1000 % 3.1
